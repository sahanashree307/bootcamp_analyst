# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_excel("C:/Users/nithy/Downloads/income.xlsx")
df.set_index("country",inplace=True)
df=df.transpose()

# %%
df
# Out:
# country  Afghanistan  Angola  Albania  Andorra     UAE  Argentina  Armenia  \
# 1800            1.33   0.779    0.919     1.88    1.65       2.08     1.36
# 1801            1.33   0.781    0.921     1.88    1.66       2.09     1.37
# 1802            1.33   0.785    0.924     1.88    1.67       2.10     1.37
# 1803            1.33   0.789    0.927     1.89    1.67       2.10     1.37
# 1804            1.33   0.791    0.929     1.89    1.68       2.11     1.38
# ...              ...     ...      ...      ...     ...        ...      ...
# 2096           12.00  21.900   59.800    88.70  102.00      61.40    33.00
# 2097           12.30  22.300   60.500    89.00  102.00      61.90    33.30
# 2098           12.60  22.700   61.100    89.30  102.00      62.40    33.60
# 2099           12.80  23.200   61.700    89.60  102.00      62.90    33.90
# 2100           13.20  23.600   62.300    89.90  103.00      63.40    34.20
#
# country  Antigua and Barbuda  Australia  Austria  ...  Uzbekistan  \
# 1800                    1.06       1.34     3.21  ...       0.576
# 1801                    1.06       1.35     3.22  ...       0.576
# 1802                    1.06       1.36     3.24  ...       0.576
# 1803                    1.06       1.36     3.25  ...       0.576
# 1804                    1.06       1.37     3.26  ...       0.576
# ...                      ...        ...      ...  ...         ...
# 2096                   62.70     108.00   107.00  ...      18.700
# 2097                   63.30     109.00   108.00  ...      18.900
# 2098                   63.80     109.00   108.00  ...      19.200
# 2099                   64.30     109.00   108.00  ...      19.500
# 2100                   64.80     110.00   108.00  ...      19.800
#
# country  St. Vincent and the Grenadines  Venezuela  Vietnam  Vanuatu  Samoa  \
# 1800                               1.21       1.23     1.53     1.49   4.15
# 1801                               1.21       1.23     1.53     1.49   4.15
# 1802                               1.21       1.22     1.53     1.49   4.15
# 1803                               1.21       1.21     1.53     1.49   4.15
# 1804                               1.21       1.21     1.53     1.49   4.15
# ...                                 ...        ...      ...      ...    ...
# 2096                              55.80      22.50    76.10    20.90  48.50
# 2097                              56.40      22.90    76.90    21.40  49.50
# 2098                              57.00      23.20    77.80    21.90  50.40
# 2099                              57.60      23.60    78.60    22.40  51.40
# 2100                              58.20      24.00    79.50    23.00  52.40
#
# country  Yemen  South Africa  Zambia  Zimbabwe
# 1800      2.02          1.76   0.973      3.22
# 1801      2.02          1.74   0.976      3.23
# 1802      2.03          1.72   0.979      3.23
# 1803      2.03          1.71   0.980      3.23
# 1804      2.04          1.69   0.983      3.24
# ...        ...           ...     ...       ...
# 2096      9.11         40.80  15.800     22.00
# 2097      9.33         41.30  16.200     22.50
# 2098      9.56         41.80  16.600     23.10
# 2099      9.79         42.30  16.900     23.70
# 2100     10.00         42.90  17.300     24.20
#
# [301 rows x 195 columns]

# %%
df["Average"]=df.mean(axis=1)

# %%
plt.figure(figsize=(5,5))
plt.plot(df["Average"],df.index,marker="o",linestyle="--",color="Blue",linewidth=1,label="Average")
plt.ylabel("Year",fontsize=12)
plt.xlabel("Average Income",fontsize=12)
plt.title("Average Income over time",fontsize=14,fontweight="bold")
plt.grid(True,linestyle="--",alpha=0.5)
plt.legend()
plt.tight_layout()
plt.show()
