# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel(r"C:\Users\sahan\Downloads\Telco_customer_churn.xlsx", sheet_name="Telco_Churn")

# %%
df['Total Charges'] = pd.to_numeric(df['Total Charges'], errors='coerce')
df['Total Charges'] = df['Total Charges'].fillna(df['Total Charges'].median())

# %%
numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns
corr_matrix = df[numeric_cols].corr()
churn_corr = corr_matrix['Churn Value'].drop('Churn Value').sort_values(ascending=False)
print("Top features positively correlated with churn:")
print(churn_corr[churn_corr > 0].head(5))
print("\nTop features negatively correlated with churn:")
print(churn_corr[churn_corr < 0].head(5))
plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()
# Out:
# Top features positively correlated with churn:
# Churn Score        0.664897
# Monthly Charges    0.193356
# Longitude          0.004594
# Zip Code           0.003346
# Name: Churn Value, dtype: float64
#
# Top features negatively correlated with churn:
# Latitude        -0.003384
# CLTV            -0.127463
# Total Charges   -0.199037
# Tenure Months   -0.352229
# Name: Churn Value, dtype: float64
