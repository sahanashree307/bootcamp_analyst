# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
population_data = pd.read_excel(r"C:\Users\sahan\Downloads\population.xlsx")
cell_phones_data = pd.read_excel(r"C:\Users\sahan\Downloads\cell_phones_total.xlsx")

# %%
df_population_numeric = population_data.set_index("country").apply(lambda col: col.map(lambda x: pd.to_numeric(str(x).replace("M", "e6").replace("k", "e3"), errors='coerce')))
global_population = df_population_numeric.sum(axis=0)
df_population_numeric
# Out:
#                    1800       1801       1802       1803       1804  \
# country
# Afghanistan   3280000.0  3280000.0  3280000.0  3280000.0  3280000.0
# Angola        1570000.0  1570000.0  1570000.0  1570000.0  1570000.0
# Albania        400000.0   402000.0   404000.0   405000.0   407000.0
# Andorra          2650.0     2650.0     2650.0     2650.0     2650.0
# UAE             40200.0    40200.0    40200.0    40200.0    40200.0
# ...                 ...        ...        ...        ...        ...
# Samoa           47300.0    47300.0    47300.0    47300.0    47300.0
# Yemen         2590000.0  2590000.0  2590000.0  2590000.0  2590000.0
# South Africa  1450000.0  1450000.0  1460000.0  1460000.0  1470000.0
# Zambia         747000.0   758000.0   770000.0   782000.0   794000.0
# Zimbabwe      1090000.0  1090000.0  1090000.0  1090000.0  1090000.0
#
#                    1805       1806       1807       1808       1809  ...  \
# country                                                              ...
# Afghanistan   3280000.0  3280000.0  3280000.0  3280000.0  3280000.0  ...
# Angola        1570000.0  1570000.0  1570000.0  1570000.0  1570000.0  ...
# Albania        409000.0   411000.0   413000.0   414000.0   416000.0  ...
# Andorra          2650.0     2650.0     2650.0     2650.0     2650.0  ...
# UAE             40200.0    40200.0    40200.0    40200.0    40200.0  ...
# ...                 ...        ...        ...        ...        ...  ...
# Samoa           47300.0    47300.0    47200.0    47200.0    47200.0  ...
# Yemen         2590000.0  2590000.0  2590000.0  2590000.0  2590000.0  ...
# South Africa  1470000.0  1480000.0  1490000.0  1490000.0  1500000.0  ...
# Zambia         806000.0   818000.0   831000.0   843000.0   856000.0  ...
# Zimbabwe      1090000.0  1090000.0  1090000.0  1090000.0  1090000.0  ...
#
#                      2091         2092         2093         2094         2095  \
# country
# Afghanistan   124000000.0  125000000.0  126000000.0  126000000.0  127000000.0
# Angola        139000000.0  140000000.0  142000000.0  143000000.0  144000000.0
# Albania         1340000.0    1320000.0    1300000.0    1290000.0    1270000.0
# Andorra           52800.0      52100.0      51500.0      50800.0      50200.0
# UAE            24100000.0   24300000.0   24500000.0   24700000.0   25000000.0
# ...                   ...          ...          ...          ...          ...
# Samoa            370000.0     372000.0     374000.0     375000.0     377000.0
# Yemen         107000000.0  107000000.0  107000000.0  108000000.0  108000000.0
# South Africa   92400000.0   92600000.0   92900000.0   93100000.0   93300000.0
# Zambia         61100000.0   61500000.0   61900000.0   62300000.0   62700000.0
# Zimbabwe       36300000.0   36400000.0   36500000.0   36600000.0   36700000.0
#
#                      2096         2097         2098         2099         2100
# country
# Afghanistan   128000000.0  128000000.0  129000000.0  130000000.0  130000000.0
# Angola        145000000.0  147000000.0  148000000.0  149000000.0  150000000.0
# Albania         1250000.0    1230000.0    1220000.0    1200000.0    1180000.0
# Andorra           49600.0      49000.0      48400.0      47800.0      47200.0
# UAE            25200000.0   25400000.0   25700000.0   25900000.0   26100000.0
# ...                   ...          ...          ...          ...          ...
# Samoa            378000.0     380000.0     381000.0     382000.0     384000.0
# Yemen         109000000.0  109000000.0  109000000.0  110000000.0  110000000.0
# South Africa   93500000.0   93700000.0   93900000.0   94100000.0   94300000.0
# Zambia         63100000.0   63400000.0   63800000.0   64100000.0   64500000.0
# Zimbabwe       36800000.0   36900000.0   37000000.0   37100000.0   37200000.0
#
# [197 rows x 301 columns]

# %%
df_cell_phones_numeric = cell_phones_data.set_index("country").apply(lambda col: col.map(lambda x: pd.to_numeric(str(x).replace("M", "e6").replace("k", "e3"), errors='coerce')))
global_cell_phones = df_cell_phones_numeric.sum(axis=0)
df_cell_phones_numeric
# Out:
#               1960  1961  1962  1963  1964  1965  1966  1967  1968  1969  ...  \
# country                                                                   ...
# Aruba          0.0   NaN   NaN   NaN   NaN   0.0   NaN   NaN   NaN   NaN  ...
# Afghanistan    0.0   NaN   NaN   NaN   NaN   0.0   NaN   NaN   NaN   NaN  ...
# Angola         0.0   NaN   NaN   NaN   NaN   0.0   NaN   NaN   NaN   NaN  ...
# Albania        0.0   NaN   NaN   NaN   NaN   0.0   NaN   NaN   NaN   NaN  ...
# Andorra        0.0   NaN   NaN   NaN   NaN   0.0   NaN   NaN   NaN   NaN  ...
# ...            ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...
# Samoa          0.0   NaN   NaN   NaN   NaN   0.0   NaN   NaN   NaN   NaN  ...
# Yemen          0.0   NaN   NaN   NaN   NaN   0.0   NaN   NaN   NaN   NaN  ...
# South Africa   0.0   NaN   NaN   NaN   NaN   0.0   NaN   NaN   NaN   NaN  ...
# Zambia         0.0   NaN   NaN   NaN   NaN   0.0   NaN   NaN   NaN   NaN  ...
# Zimbabwe       0.0   NaN   NaN   NaN   NaN   0.0   NaN   NaN   NaN   NaN  ...
#
#                     2014        2015        2016        2017        2018  \
# country
# Aruba           140000.0    141000.0         NaN         NaN         NaN
# Afghanistan   18400000.0  19700000.0  21600000.0  23900000.0  22000000.0
# Angola        14100000.0  13900000.0  13000000.0  13300000.0  13300000.0
# Albania        3360000.0   3400000.0   3370000.0   3630000.0   2710000.0
# Andorra          66200.0     71300.0     76100.0     80300.0     82600.0
# ...                  ...         ...         ...         ...         ...
# Samoa           107000.0    121000.0    151000.0    124000.0    100000.0
# Yemen         17100000.0  15000000.0  16400000.0  15400000.0  15300000.0
# South Africa  79300000.0  88000000.0  82400000.0  88500000.0  92400000.0
# Zambia        10100000.0  11600000.0  12000000.0  13400000.0  15500000.0
# Zimbabwe      11800000.0  12800000.0  12900000.0  14100000.0  12900000.0
#
#                     2019        2020         2021         2022         2023
# country
# Aruba           141000.0    141000.0     141000.0          NaN          NaN
# Afghanistan   22600000.0  22700000.0   22700000.0   22800000.0   23000000.0
# Angola        14800000.0  14600000.0   15300000.0   23700000.0   25700000.0
# Albania        2630000.0   2620000.0    2640000.0    2780000.0    2610000.0
# Andorra          87900.0     80400.0      93800.0     114000.0     126000.0
# ...                  ...         ...          ...          ...          ...
# Samoa            84000.0     69000.0      69000.0     134000.0          NaN
# Yemen         15200000.0  15200000.0   17800000.0   17800000.0   20000000.0
# South Africa  97000000.0  96000000.0  100000000.0  100000000.0  108000000.0
# Zambia        17200000.0  19100000.0   20200000.0   19800000.0   21200000.0
# Zimbabwe      13200000.0  13200000.0   14300000.0   14300000.0   15000000.0
#
# [214 rows x 64 columns]

# %%
cell_phones_per_person = (global_cell_phones / global_population).dropna()
cell_phones_per_person_df = cell_phones_per_person.reset_index()
cell_phones_per_person_df.columns = ["Year", "Cell Phones per Person"]
plt.figure(figsize=(10, 6))
plt.plot(cell_phones_per_person_df["Cell Phones per Person"], cell_phones_per_person_df["Year"], marker="o", linestyle="-", color="b")
plt.xlabel("Number of Cell Phones per Person")
plt.ylabel("Year")
plt.title("Rise of Cell Phones per Person Over Time")
plt.grid(True)
plt.show()
